# %% [markdown]
# <h1> Imports<h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>7.1</h1>

# %%
data = pd.read_csv("Housing.csv", sep=',')
data.rename(columns={'Unnamed: 0':'longitude'}, inplace=True)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# <h1>7.2</h1>

# %%
data = data.dropna()
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# <h1>7.3</h1>

# %%
ocean_proximity_count = data["ocean_proximity"].value_counts()
ocean_proximity_count
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# <h1>7.4</h1>

# %%
plt.figure(figsize=(15,7))
plt.scatter(data.iloc[:,0], data.iloc[:,1])
plt.show()

# %% [markdown]
# In the above scatter plot we can figure out distribution of data
#
# <img src="distribution.png" alt="large distributions image" style="height: 600px; width:1000px;"/>

# %% [markdown]
# <h1> Temporal</h1>

# %%
import pandas as pd
# Out:
# Running cells with 'VENV' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"/home/yasin/Desktop/IUT/Data mining/HW/VENV/bin/python" -m pip install ipykernel -U --force-reinstall'
